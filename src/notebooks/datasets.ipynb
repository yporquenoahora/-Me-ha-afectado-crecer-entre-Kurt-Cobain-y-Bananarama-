# %% [markdown]
# <a href="https://colab.research.google.com/github/yporquenoahora/EDA/blob/master/src/notebooks/datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Collecting data for the project</h1>

# %% [markdown]
# # EDA test snippets
#
# instead of directly interacting with the Spotify Restful API, I use a lightweight Python wrapper for ease.

# %%
# %pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)

# %%
import pandas as pd
import numpy as np

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
# spotify credentials for the application:
# "Related Artist Network Visualizer"
client_id = '03399882ee014a03b7c5c7bf31d54c00'
client_secret = '8fb28399b6b741828bde4d3327f02135'
# create a credential manager and api layer
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Track info for analysis
#
# I'll start with a root node of on of my favorite artists, [Bassnectar](https://www.bassnectar.net).

# %%
# the spotify id for the artist Bassnectar
#NIN
#seed_artist = 'spotify:artist:1mCHLu4gizrN9PwHxKrJv4'
seed_artist = 'spotify:artist:0X380XXQSNBYuleKzav5UO'

# %% [markdown]
# Get a Node of a song

# %%
seed_song = "spotify:track:5mc6EyF1OIEOhAkD0Gg9Lc"

# %%
song = sp.track("5mc6EyF1OIEOhAkD0Gg9Lc")
album = song.get("album")
artitst = song.get("artists")
id = "5mc6EyF1OIEOhAkD0Gg9Lc"
dSong = pd.DataFrame([song])
dAlbum = pd.DataFrame([album])
dArtists = pd.DataFrame([artitst[0]])

# %%
dAlbum
# Out:
#   album_group album_type                                            artists  \
# 0       album      album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  \
# 0  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/5I...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/5I7lLu8xXJfG...  5I7lLu8xXJfGRdFUqHaLQU
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                    name release_date release_date_precision  \
# 0  The Downward Spiral (Deluxe Edition)   1994-03-08                    day
#
#    total_tracks   type                                   uri
# 0            27  album  spotify:album:5I7lLu8xXJfGRdFUqHaLQU

# %%
dArtists
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/0...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/0X380XXQSNB...  0X380XXQSNBYuleKzav5UO
#
#               name    type                                    uri
# 0  Nine Inch Nails  artist  spotify:artist:0X380XXQSNBYuleKzav5UO

# %%
dSong.iloc[:,3:]
# Out:
#    disc_number  duration_ms  explicit              external_ids  \
# 0            1       373306      True  {'isrc': 'USIR19400529'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/5m...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/5mc6EyF1OIEO...  5mc6EyF1OIEOhAkD0Gg9Lc
#
#    is_local    name  popularity  \
# 0     False  Closer          64
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/b4548943ec88c0ed...             5  track
#
#                                     uri
# 0  spotify:track:5mc6EyF1OIEOhAkD0Gg9Lc

# %%
album = song.get("album")
year = album.get("release_date")
print( album.get("name"), year)
# Out:
# The Downward Spiral (Deluxe Edition) 1994-03-08

# %%
#https://developer.spotify.com/documentation/web-api/reference/#/operations/get-track
#https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-audio-features
#https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-audio-analysis
analisys = sp.audio_analysis("11dFghVXANMlKmJXsNCbNl")
meta = analisys.get("meta")
track = analisys.get("track")
bars = analisys.get("bars")
beats = analisys.get("beats")
sections = analisys.get("sections")
segments = analisys.get("segments")
tatums = analisys.get("tatums")
features = sp.audio_features("11dFghVXANMlKmJXsNCbNl")

# %%
a_meta = pd.DataFrame([meta])
a_track = pd.DataFrame([track])
a_bars = pd.DataFrame(bars)
a_beats = pd.DataFrame(beats)
a_sections = pd.DataFrame(sections)
a_segments = pd.DataFrame(segments)
a_tatums = pd.DataFrame(tatums)

a_meta
# Out:
#   analyzer_version platform detailed_status  status_code   timestamp  \
# 0            4.0.0    Linux              OK            0  1495193577
#
#    analysis_time                   input_process
# 0        6.93906  libvorbisfile L+R 44100->22050

# %%
a_track
# Out:
#    num_samples   duration sample_md5  offset_seconds  window_seconds  \
# 0      4585515  207.95985                          0               0
#
#    analysis_sample_rate  analysis_channels  end_of_fade_in  start_of_fade_out  \
# 0                 22050                  1             0.0          201.13705
#
#    loudness  ...  mode  mode_confidence  \
# 0    -2.743  ...     1            0.485
#
#                                           codestring  code_version  \
# 0  eJxVmgl2LDcOBK_SR-C-3P9ijki2vuSZZ1tkVbO4AIlMgL...          3.15
#
#                                      echoprintstring  echoprint_version  \
# 0  eJzdnQ2SJDlurK8U_CePw9_7H0GfI_dNzbRZMGVWGpPsab...               4.12
#
#                                          synchstring  synch_version  \
# 0  eJxNWglyHDEI_IqeMCB0_f9jUR9ap5yy95iREDRNwyTzG1...            1.0
#
#                                         rhythmstring  rhythm_version
# 0  eJx1XFmW4zgOvIqPwJ3g_S82jAW0s_rNR3Zm2RLFJQAEAl...             1.0
#
# ...

# %%
a_bars
# Out:
#         start  duration  confidence
# 0     0.49567   2.18749       0.925
# 1     2.68316   2.10995       0.707
# 2     4.79311   2.17781       0.091
# 3     6.97092   2.22058       0.093
# 4     9.19150   2.23333       0.207
# ..        ...       ...         ...
# 92  192.32745   2.09087       0.528
# 93  194.41832   2.08398       0.261
# 94  196.50230   2.08674       0.124
# 95  198.58904   2.08615       0.417
# 96  200.67519   2.10169       0.000
#
# [97 rows x 3 columns]

# %%
a_beats
# Out:
#          start  duration  confidence
# 0      0.49567   0.56431       0.612
# 1      1.05998   0.54896       0.325
# 2      1.60894   0.53701       0.228
# 3      2.14594   0.53722       0.643
# 4      2.68316   0.53331       0.820
# ..         ...       ...         ...
# 381  200.67519   0.52347       0.351
# 382  201.19865   0.52198       0.200
# 383  201.72064   0.52695       0.081
# 384  202.24759   0.52929       0.046
# 385  202.77689   0.52929       0.053
#
# [386 rows x 3 columns]

# %%
a_sections
# Out:
#        start  duration  confidence  loudness    tempo  tempo_confidence  key  \
# 0    0.00000   6.97092       1.000   -14.938  113.178             0.647    9
# 1    6.97092  23.10418       0.829    -7.771  109.173             0.501    9
# 2   30.07511  34.42440       0.743    -1.593  115.020             0.458    9
# 3   64.49950  28.70392       0.860    -6.108  115.066             0.575   11
# 4   93.20342  35.98939       0.730    -1.492  115.081             0.495    9
# 5  129.19281  20.87669       0.614    -3.597  114.954             0.591   11
# 6  150.06950  57.89036       0.701    -1.024  114.986             0.390    2
#
#    key_confidence  mode  mode_confidence  time_signature  \
# 0           0.297     1            0.471               4
# 1           0.162     0            0.319               4
# 2           0.000     1            0.214               4
# 3           0.540     0            0.486               4
# 4           0.000     1            0.026               4
# ...

# %%
a_segments
# Out:
#          start  duration  confidence  loudness_start  loudness_max_time  \
# 0      0.00000   0.24317       1.000         -59.656            0.21478
# 1      0.24317   0.26240       0.975         -34.039            0.07659
# 2      0.50558   0.19596       0.362         -24.576            0.07177
# 3      0.70154   0.19891       0.435         -23.053            0.07305
# 4      0.90045   0.12082       0.253         -18.084            0.00395
# ..         ...       ...         ...             ...                ...
# 761  200.91737   0.26009       0.614          -6.545            0.12574
# 762  201.17746   0.18009       0.167          -3.485            0.00562
# 763  201.35754   0.54050       0.464          -4.748            0.09921
# 764  201.89806   1.07964       0.300          -6.688            0.05800
# 765  202.97769   4.98218       0.054         -23.839            0.05905
#
#      loudness_max  loudness_end  \
# 0         -36.317           0.0
# 1         -20.161           0.0
# ...

# %%
a_tatums
# Out:
#          start  duration  confidence
# 0      0.49567   0.28215       0.612
# 1      0.77782   0.28215       0.612
# 2      1.05998   0.27448       0.325
# 3      1.33446   0.27448       0.325
# 4      1.60894   0.26850       0.228
# ..         ...       ...         ...
# 767  201.98412   0.26348       0.081
# 768  202.24759   0.26464       0.046
# 769  202.51224   0.26464       0.046
# 770  202.77689   0.26464       0.053
# 771  203.04153   0.26464       0.053
#
# [772 rows x 3 columns]

# %%
f = pd.DataFrame([features])
f
# Out:
#                                                    0
# 0  {'danceability': 0.696, 'energy': 0.905, 'key'...

# %%
#join track, features and analysis in one column

# %% [markdown]
# <h1>Search and gather songs from the decades we want</h1>

# %% [markdown]
# List of most listened songs from 1951
# https://open.spotify.com/playlist/6KOwiWg5zwrt83nEcx7HyI

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
playlist_URI ="6KOwiWg5zwrt83nEcx7HyI"
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]
playlist_len = len(track_uris)

# %%
track_uris = np.empty((playlist_len), dtype=object)
track_ids = np.empty((playlist_len),  dtype=object)
track_names = np.empty((playlist_len),  dtype=object)

aAnalisysTrack = []
aAnalisysBeats = []
aAnalisysSections = []
aAnalisysSegments = []
aAnalisysTatums = []


playlist_tracks = sp.playlist_tracks(playlist_URI)["items"]

tracks = []
for i in playlist_tracks:
    t = i.get("track")
    album_release = t.get("album").get("release_date")    
    t.update({"release_date": album_release})
    tracks.append(t)
dfTracks = pd.DataFrame(tracks)
dfTracks.head()
# Out:
#                                                album  \
# 0  {'album_group': 'compilation', 'album_type': '...
# 1  {'album_group': 'compilation', 'album_type': '...
# 2  {'album_group': 'compilation', 'album_type': '...
# 3  {'album_group': 'compilation', 'album_type': '...
# 4  {'album_group': 'album', 'album_type': 'album'...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0                                                 []            1
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2                                                 []            1
# ...

# %%
aFeatures = []
dfFeatures = {}
for ix,track in enumerate(playlist_tracks):
 
    #URI
    track_uri = track["track"]["uri"]
    track_uris[ix] = track["track"]["uri"]
    track_id = track_uri.split(":")[2]
    track_ids[ix] = track_id
    
    #Track name
    track_name = track["track"]["name"]
    track_names[ix] = track_name
    
    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)

    
    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_genres = artist_info["genres"]
    
    #Album
    album = track["track"]["album"]["name"]
    release_date = track["track"]["album"]["release_date"]
    
    #Popularity of the track
    track_pop = track["track"]["popularity"]
    
    #features.append(sp.audio_features(track_uri))
    features = sp.audio_features(track_uri)[0]
    features.update({"id":track_id, "names":track_name,"artists":artist_name, "genre": artist_genres, "release_date": release_date, "popularity": artist_info["popularity"]})
    
    
    #analisys = sp.audio_analysis(track_uri)
    

    aFeatures.append(features)
        

#df = pd.DataFrame({ "names": track_names, "artists":artist_name, "id":  track_id})
df = pd.DataFrame(aFeatures, columns = ["names", "artists", "release_date","id", "genre", "popularity"])

df.head()
# Out:
# Index(['names', 'artists', 'release_date', 'id', 'genre', 'popularity'], dtype='object')

# %%
#canciones por genero


sGenres = df["genre"]
genres_list = set()

for i,r in sGenres.items():       
        for item in r:          
          genres_list.add(item)
          
print(genres_list)

res = {}
for index, row in df.iterrows():       
    for gen in row.genre:
        res[gen] = (row.name)
            
dfGenres = pd.DataFrame([res])
dfGenres.to_csv("../data/songs_genres.csv")
dfGenres
# Out:
# {'easy listening', 'vocal harmony group', 'jazz clarinet', 'classic italian pop', 'rockabilly', 'deep adult standards', 'soft rock', 'doo-wop', 'folk', 'canadian pop', 'mambo', 'vocal jazz', 'cowboy western', 'canadian country', 'nashville sound', 'library music', 'big band', 'italian adult pop', 'laboratorio', 'space age pop', 'lounge', 'rock-and-roll', 'soul', "man's orchestra", 'american folk revival', 'new orleans blues', 'novelty', 'movie tunes', 'swing', 'tin pan alley', 'classic soundtrack', 'torch song', 'bubblegum pop', 'american modern classical', 'louisiana blues', 'exotica', 'adult standards', 'sunshine pop', 'memphis blues', 'rhythm and blues', 'mellow gold'}
#    adult standards  easy listening  lounge  vocal jazz  space age pop  swing  \
# 0               99              90      95          85             75     85
#
#    torch song  american folk revival  folk  american modern classical  ...  \
# ...

# %%
dFeatures = pd.DataFrame(aFeatures, columns = aFeatures[0].keys())
dFeatures.head()
print(dFeatures.columns, df.columns)
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'names', 'artists', 'genre', 'release_date'],
#       dtype='object') Index(['names', 'artists', 'release_date', 'id'], dtype='object')

# %%
print(type(df), type(dFeatures))
res = pd.merge(df, dFeatures, how="inner", on=['names', 'artists', 'release_date', 'id']).set_index("id")
res = res[res.release_date != "0000"] 
res.columns
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>
# Index(['names', 'artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature', 'genre'],
#       dtype='object')

# %%
#collect info of the songs and dump it into a convenient data structure
#release year, name, link, artists
#song_features
res.to_csv('../data/songs.csv')

# %% [markdown]
# Caso de estudio: mi propia cuenta de Spotify

# %%
# Shows the top tracks for a user

import spotipy
from spotipy.oauth2 import SpotifyOAuth

scope = 'user-top-read'

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id="9d24693b130840829fc41aabcada8c66",
                                               client_secret="1d8ba6c6e2ab4c8aa0bac0f3fe408142",
                                               redirect_uri="http://localhost:1234",
                                               scope='user-top-read user-follow-read'))


ranges = ['short_term', 'medium_term', 'long_term']
subset = []
for sp_range in ranges:
    #print("range:", sp_range)
    results = sp.current_user_top_tracks(time_range=sp_range, limit=50)
    for i, item in enumerate(results['items']):                 
        artist_uri = item["artists"][0]["uri"]
        artist_info = sp.artist(artist_uri)        
        artist_genres = artist_info["genres"]
        subset.append([item["name"],item['artists'][0]['name'], item["album"]["release_date"],sp_range,item["id"], artist_genres,artist_info["popularity"]])

aFeatures = []
dfFeatures = {}
print(subset)

for ix,track in enumerate(subset):
    features = sp.audio_features(track[4])[0]
    aFeatures.append(features)

df = pd.DataFrame(aFeatures)

dfMostListened = pd.DataFrame(subset,  columns=["name", "artists","release_date", "range", "id", "genre", "popularity" ])

myConcatDF = pd.concat([dfMostListened, df], axis=1)
print(myConcatDF.columns)
myConcatDF.to_csv("../data/my_most_listened.csv")
# Out:
# [['Mon Amour - Remix', 'zzoilo', '2021-12-14', 'short_term', '5TAbg7lJkmo1ZO8pCNhchW', [], 66], ['Foto Pa Ti', 'Mariel Mariel', '2014-02-18', 'short_term', '6fZVXHccQe6EbXavK9FLHg', ['chilean indie', 'deep latin alternative'], 41], ['Amiga mía', 'Alejandro Sanz', '1997-08-28', 'short_term', '6kQYMqjobmB8MkWwa9OUyA', ['cantautor', 'latin arena pop', 'latin pop', 'mexican pop', 'rock en espanol', 'spanish pop'], 79], ['Pena, Penita, Pena!', 'Vinila von Bismark', '2015-11-18', 'short_term', '2HKEJSEYuRt3892pFxswAC', ['granada indie'], 33], ['Quiero Decirte al Oído', 'Vinila von Bismark', '2017-11-17', 'short_term', '4CtJ0UCxMnzmlyOtbTYgBe', ['granada indie'], 33], ['Poison Lips', 'Vitalic', '2009-09-28', 'short_term', '2BIC788t4sLhFM8MpZIclI', ['alternative dance', 'electro house', 'electroclash', 'electronica', 'filter house', 'french indietronica', 'french techno', 'new rave'], 53], ['Back To Black', 'Amy Winehouse', '2006', 'short_term', '3FAclTFfvUuQYnEsptbK8w', ['british soul', 'ne
# ...

# %%
for i in ['doo-wop', 'vocal harmony group']:
    print(i)
# Out:
# doo-wop
# vocal harmony group

# %%
#canciones por genero


sGenres = myConcatDF["genre"]
genres_list = set()

for i,r in sGenres.items():       
        for item in r:          
          genres_list.add(item)
          
print(genres_list)

res = {}
for index, row in df.iterrows():      
    print(gen, row.genre, gen in row.genre)
    for gen in row.genre:
        res[gen] = (row.name)
print(res)
dfGenres = pd.DataFrame([res])
dfGenres.to_csv("../data/my_songs_genres.csv")
dfGenres
# Out:
# {'nu-cumbia', 'punk', 'spanish electronic', 'country', 'french techno', 'neo soul', 'rap marseille', 'doo-wop', 'french indietronica', 'deep new americana', 'zolo', 'new rave', 'eurodance', 'dance rock', 'arkansas country', 'british soul', 'power pop', 'industrial', 'hip-hop experimental', 'rock-and-roll', 'olympia wa indie', 'experimental indie rock', 'spanish new wave', 'electropop', 'granada indie', 'soul', 'art punk', 'pop electronico', 'spanish rockabilly', 'new wave pop', 'electronic rock', 'electronica', 'torch song', 'album rock', 'northern soul', 'riot grrrl', 'outlaw country', 'latin pop', 'rhythm and blues', 'disco', 'synthpop', 'instrumental funk', 'rap latina', 'tropical alternativo', 'mexican pop', 'british alternative rock', 'industrial metal', 'socal pop punk', 'chicago soul', 'brazilian rock', 'latin arena pop', 'alternative dance', 'sophisti-pop', 'queercore', 'modern rock', 'europop', 'spanish synthpop', 'electro house', 'musica mexicana', 'soul blues', 'country ro
# ...

# %%
myConcatDF.head()
# Out:
#                      name             artists release_date       range  \
# 0       Mon Amour - Remix              zzoilo   2021-12-14  short_term
# 1              Foto Pa Ti       Mariel Mariel   2014-02-18  short_term
# 2               Amiga mía      Alejandro Sanz   1997-08-28  short_term
# 3  Quiero Decirte al Oído  Vinila von Bismark   2017-11-17  short_term
# 4             Poison Lips             Vitalic   2009-09-28  short_term
#
#                        id                                              genre  \
# 0  5TAbg7lJkmo1ZO8pCNhchW                                                 []
# 1  6fZVXHccQe6EbXavK9FLHg            [chilean indie, deep latin alternative]
# 2  6kQYMqjobmB8MkWwa9OUyA  [cantautor, latin arena pop, latin pop, mexica...
# 3  4CtJ0UCxMnzmlyOtbTYgBe                                    [granada indie]
# 4  2BIC788t4sLhFM8MpZIclI  [alternative dance, electro house, electroclas...
#
#    danceability  energy  key  loudness  ...  liveness  valence    tempo  \
# ...

# %%
# Shows the recently played tracks for a user

import spotipy
from spotipy.oauth2 import SpotifyOAuth

scope = 'user-read-recently-played'

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id="9d24693b130840829fc41aabcada8c66",
                                               client_secret="1d8ba6c6e2ab4c8aa0bac0f3fe408142",
                                               redirect_uri="http://localhost:1234",
                                               scope='user-read-recently-played'))


subset = []
results = sp.current_user_recently_played(limit=50)

for ix,item in enumerate(results["items"]):    
    artist_uri = item["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)
    artist_genres = artist_info["genres"]
    subset.append([item["track"]["name"],item["track"]['artists'][0]['name'], item["track"]["album"]["release_date"],item["track"]["id"], artist_genres])
    
aFeatures = []
dfFeatures = {}


for ix,track in enumerate(subset):
    features = sp.audio_features(track[3])[0]
    aFeatures.append(features)

df = pd.DataFrame(aFeatures)

dfMostRecentListened = pd.DataFrame(subset,  columns=["name", "artists","release_date", "id", "genre" ])

myConcatRecentDF = pd.concat([dfMostRecentListened, df], axis=1)
myConcatRecentDF.to_csv("../data/my_most_recently_listened.csv")

# %%
#canciones guardadas
import spotipy
from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id="03399882ee014a03b7c5c7bf31d54c00",
                                               client_secret="8fb28399b6b741828bde4d3327f02135",
                                               redirect_uri="http://localhost:1234",
                                               scope="user-library-read"))

saved_tracks = sp.current_user_saved_tracks()

#results = sp.current_user_top_tracks()
for idx, item in enumerate(saved_tracks['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
df = pd.DataFrame(saved_tracks)
#df["items"][0]
# Out:
# 0 Los Tiki Phantoms  –  La Chica Yeye
# 1 Duran Duran  –  Ordinary World
# 2 Starsailor  –  Four to the Floor - Thin White Duke Mix; Short Version
# 3 Aerosmith  –  Dream On
# 4 Ginebras  –  La Típica Canción
# 5 Tropical Fuck Storm  –  Stayin' Alive
# 6 Melt Yourself Down  –  Crocodile
# 7 Robyn  –  With Every Heartbeat
# 8 Lalalar  –  Mecnun'dan Beter Haldeyim - Radio Edit
# 9 Demdike Stare  –  Curzon
# 10 The Green Windows  –  The Gospel According to Tony Day
# 11 daniel zolani  –  Fights for Lives
# 12 daniel zolani  –  Over While Wall
# 13 Antony Redau  –  Birds Trips
# 14 daniel zolani  –  Wife Regrets
# 15 Calle 13  –  Intro - El Viaje (feat. Eduardo Galeano)
# 16 Calle 13  –  Ojos Color Sol (feat. Silvio Rodríguez)
# 17 Calle 13  –  Multi_Viral (feat. Julian Assange, Kamilya Jubran & Tom Morello)
# 18 Calle 13  –  Interludio - Stupid Is as Stupid Does (feat. John Leguizamo)
# 19 Calle 13  –  Los Idiotas

# %%
#efemerides

# %%
#join

# %% [markdown]
# <h1>Generate a dictionary where we can map the value of a single feature to a color we visualize</h1>

# %%
#diccionay with ranges

# %% [markdown]
# We also may need a legend to make understandable the visualization

# %%
#legend

# %%
#the ranges wil probably be dinamic

# %% [markdown]
# <h1>Dump info into file or files</h1>
